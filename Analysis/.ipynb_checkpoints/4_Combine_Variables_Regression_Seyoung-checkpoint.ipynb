# %%
import pandas as pd
import numpy as np

# %%
# load features and outcome
features_list = []
for i in range(2, 7):
    file_name = "scaled_variables_session_" + str(i) + ".csv"
    features = pd.read_csv('../EPM_dataset/Data/Seyoung/' + file_name)
    features_list.append(features)
    
outcome = pd.read_csv('../EPM_dataset/Data/Seyoung/grades.csv')

# %%
# verify
features_list[3]
# Out:
#      ID  DUR_Aulaweb  DUR_Blank  DUR_Deeds  DUR_Diagram  DUR_Other  \
# 0     1     0.105371   0.105120   0.105446     0.105440   0.102610
# 1     2     0.105365   0.105124   0.105409     0.105362   0.102637
# 2     3     0.105365   0.105188   0.105409     0.105350   0.102687
# 3     4     0.105434   0.105293   0.105407     0.105369   0.102628
# 4     5     0.105365   0.105148   0.105406     0.105378   0.102610
# ..  ...          ...        ...        ...          ...        ...
# 86  100     0.105371   0.105123   0.105408     0.105388   0.102631
# 87  101     0.105365   0.105121   0.105405     0.105357   0.102617
# 88  102     0.105365   0.105121   0.105413     0.105381   0.102694
# 89  103     0.105369   0.105576   0.105407     0.105378   0.102871
# 90  104     0.105369   0.105149   0.105406     0.105377   0.102694
#
#     DUR_Properties  DUR_Study  DUR_TextEditor  KS_Aulaweb  KS_Blank  KS_Deeds  \
# 0         0.105324   0.105396        0.105407   -0.230749 -0.380389 -0.088532
# 1         0.105234   0.105394        0.105407   -0.230749  0.652906 -0.697501
# 2         0.105234   0.105414        0.105407   -0.230749  0.136259 -0.328126
# 3         0.105241   0.105389        0.105407    1.553411  0.523744 -0.268227
# 4         0.105293   0.105390        0.105407   -0.230749 -0.380389 -0.018650
# ..             ...        ...             ...         ...       ...       ...
# 86        0.105240   0.105393        0.105408    0.180980  2.073686  0.111131
# 87        0.105234   0.105388        0.105406   -0.230749 -0.380389 -0.777366
# 88        0.105234   0.105385        0.105408    0.043737 -0.380389 -0.248261
# 89        0.105237   0.105499        0.105407   -0.230749  0.136259 -0.158413
# 90        0.105234   0.105387        0.105406   -0.230749 -0.380389  2.397262
#
#     KS_Diagram
# 0    -0.382027
# 1    -0.472796
# 2    -0.472796
# 3     1.977965
# 4    -0.382027
# ..         ...
# 86   -0.018952
# 87   -0.109721
# 88   -0.472796
# 89   -0.472796
# 90    0.298739
#
# [91 rows x 13 columns]

# %%
outcome
# Out:
#     Unnamed: 0   ID    MID2   MID3   MID4   MID5   MID6  FIN2  FIN3  FIN4  \
# 0            0    1   83.33    0.0   90.0  100.0  56.25  11.0  37.0  55.0
# 1            1    2   66.67   87.5   90.0  100.0  25.00  12.0  35.0  23.0
# 2            2    3   58.33   87.5   90.0  100.0   0.00  41.0  37.0  55.0
# 3            3    4  100.00  100.0  100.0   87.5  68.75  11.0   5.0  19.0
# 4            4    5   83.33  100.0  100.0  100.0  68.75  32.0  37.0  11.0
# ..         ...  ...     ...    ...    ...    ...    ...   ...   ...   ...
# 88          88  101   75.00   37.5    0.0   87.5   0.00  20.5  33.0  15.0
# 89          89  102   75.00  100.0   80.0   87.5  50.00  31.0  33.0  24.0
# 90          90  103   33.33    0.0    0.0   87.5   0.00  31.0  35.0   3.0
# 91          91  104  100.00    0.0   90.0  100.0  68.75  31.0  37.0  51.0
# 92          92  106    0.00   87.5    0.0    0.0   0.00   1.5  37.0  19.0
#
#     FIN5  FIN6  RES2  RES3  RES4  RES5  RES6
# 0   32.0  57.5     1     0     0     1     0
# 1   15.0   5.0     1     0     0     1     0
# 2   26.0  55.5     0     0     0     1     0
# 3    1.5  17.5     1     1     1     1     0
# 4   20.5   4.5     0     0     1     1     1
# ..   ...   ...   ...   ...   ...   ...   ...
# 88   0.0   0.0     0     0     0     1     0
# 89   0.0   4.5     0     0     0     1     1
# 90   0.0   0.0     0     0     0     1     0
# 91  30.0  57.0     0     0     0     1     0
# 92   0.0  44.5     0     0     0     0     0
#
# [93 rows x 17 columns]

# %%
# leave relevant columns only
outcome = outcome[['ID', 'RES2', 'RES3', 'RES4', 'RES5', 'RES6']]
outcome
# Out:
#      ID  RES2  RES3  RES4  RES5  RES6
# 0     1     1     0     0     1     0
# 1     2     1     0     0     1     0
# 2     3     0     0     0     1     0
# 3     4     1     1     1     1     0
# 4     5     0     0     1     1     1
# ..  ...   ...   ...   ...   ...   ...
# 88  101     0     0     0     1     0
# 89  102     0     0     0     1     1
# 90  103     0     0     0     1     0
# 91  104     0     0     0     1     0
# 92  106     0     0     0     0     0
#
# [93 rows x 6 columns]

# %%
# merge features and outcome
for i, features in enumerate(features_list):
    features_list[i] = features.merge(outcome[['ID', 'RES' + str(i+2)]], how='inner', on='ID')
    features_list[i] = features_list[i].rename(columns={'RES' + str(i+2): 'Y'})

# %%
# verify
features_list[3]
# Out:
#      ID  DUR_Aulaweb  DUR_Blank  DUR_Deeds  DUR_Diagram  DUR_Other  \
# 0     1     0.105371   0.105120   0.105446     0.105440   0.102610
# 1     2     0.105365   0.105124   0.105409     0.105362   0.102637
# 2     3     0.105365   0.105188   0.105409     0.105350   0.102687
# 3     4     0.105434   0.105293   0.105407     0.105369   0.102628
# 4     5     0.105365   0.105148   0.105406     0.105378   0.102610
# ..  ...          ...        ...        ...          ...        ...
# 79  100     0.105371   0.105123   0.105408     0.105388   0.102631
# 80  101     0.105365   0.105121   0.105405     0.105357   0.102617
# 81  102     0.105365   0.105121   0.105413     0.105381   0.102694
# 82  103     0.105369   0.105576   0.105407     0.105378   0.102871
# 83  104     0.105369   0.105149   0.105406     0.105377   0.102694
#
#     DUR_Properties  DUR_Study  DUR_TextEditor  KS_Aulaweb  KS_Blank  KS_Deeds  \
# 0         0.105324   0.105396        0.105407   -0.230749 -0.380389 -0.088532
# 1         0.105234   0.105394        0.105407   -0.230749  0.652906 -0.697501
# 2         0.105234   0.105414        0.105407   -0.230749  0.136259 -0.328126
# 3         0.105241   0.105389        0.105407    1.553411  0.523744 -0.268227
# 4         0.105293   0.105390        0.105407   -0.230749 -0.380389 -0.018650
# ..             ...        ...             ...         ...       ...       ...
# 79        0.105240   0.105393        0.105408    0.180980  2.073686  0.111131
# 80        0.105234   0.105388        0.105406   -0.230749 -0.380389 -0.777366
# 81        0.105234   0.105385        0.105408    0.043737 -0.380389 -0.248261
# 82        0.105237   0.105499        0.105407   -0.230749  0.136259 -0.158413
# 83        0.105234   0.105387        0.105406   -0.230749 -0.380389  2.397262
#
#     KS_Diagram  Y
# 0    -0.382027  1
# 1    -0.472796  1
# 2    -0.472796  1
# 3     1.977965  1
# 4    -0.382027  1
# ..         ... ..
# 79   -0.018952  1
# 80   -0.109721  1
# 81   -0.472796  1
# 82   -0.472796  1
# 83    0.298739  1
#
# [84 rows x 14 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
for i, session in enumerate(features_list):
#     if i == 3: continue
    X = session.drop(columns=['ID', 'Y'])
    y = session['Y']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
    logmodel = LogisticRegression()
    logmodel.fit(X_train, y_train)
    predictions = logmodel.predict(X_test)
    print(f'==========Session{str(i+2)}===============')
    print('accuracy_score : ', accuracy_score(y_test, predictions))
    print('confusion_matrix :\n ', confusion_matrix(y_test, predictions))
    print('\n')
# Out:
# ==========Session2===============
# accuracy_score :  0.6521739130434783
# confusion_matrix :
#   [[13  4]
#  [ 4  2]]
#
#
# ==========Session3===============
# accuracy_score :  0.8333333333333334
# confusion_matrix :
#   [[20  0]
#  [ 4  0]]
#
#
# ==========Session4===============
# accuracy_score :  0.6666666666666666
# confusion_matrix :
#   [[17  3]
#  [ 6  1]]
#
#
# ==========Session5===============
# accuracy_score :  0.9615384615384616
# confusion_matrix :
#   [[ 0  0]
#  [ 1 25]]
#
#
# ==========Session6===============
# accuracy_score :  0.7083333333333334
# confusion_matrix :
#   [[14  1]
#  [ 6  3]]
