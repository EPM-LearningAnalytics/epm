# %%
from epm.graph import *

# %%
mid_avg()
# Out:
#     Student Id    Session  Avg_grades
# 0      Average  Session 2        2.89
# 1      Average  Session 3        2.13
# 2      Average  Session 4        3.94
# 3      Average  Session 5        3.03
# 4      Average  Session 6        1.70
# ..         ...        ...         ...
# 570        111  Session 6        0.00
# 571        112  Session 6        0.00
# 572        113  Session 6        0.00
# 573        114  Session 6        0.00
# 574        115  Session 6        0.00
#
# [580 rows x 3 columns]

# %%
mid_grades= pd.read_excel('data/intermediate_grades.xlsx',engine='openpyxl')
#calculate the mean
# mid_avg = pd.DataFrame(mid_grades.mean(axis=0))
# mid_avg = mid_avg.drop(['Student Id'])
# mid_avg.reset_index(inplace = True)

# %%
calculate the Q1
mid_avg_Q1 = pd.DataFrame(mid_grades.quantile(q=0.25, axis=0))
mid_avg_Q1 = mid_avg_Q1.drop(['Student Id'])
mid_avg_Q1.reset_index(inplace = True)
mid_avg_Q1.columns = ['Session', 'Avg_grades']
mid_avg_Q1.insert(0, "Student Id", 'Q1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-c36b7fa7fd47> in <module>
#       1 # calculate the Q1
#       2 mid_avg_Q1 = pd.DataFrame(mid_avg.quantile(q=0.25, axis=0))
# ----> 3 mid_avg_Q1 = mid_avg_Q1.drop(['Student Id'])
#       4 mid_avg_Q1.reset_index(inplace = True)
#       5 mid_avg_Q1.columns = ['Session', 'Avg_grades']
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Student Id'] not found in axis"

# %%
mid_avg_Q1
# Out:
#   Student Id    Session  Avg_grades
# 0         Q1  Session 2       0.000
# 1         Q1  Session 3       0.500
# 2         Q1  Session 4       4.000
# 3         Q1  Session 5       3.000
# 4         Q1  Session 6       0.125

# %%
#calculate the Q3
mid_avg_Q3 = pd.DataFrame(mid_grades.quantile(q=0.75, axis=0))
mid_avg_Q3 = mid_avg_Q3.drop(['Student Id'])
mid_avg_Q3.reset_index(inplace = True)
mid_avg_Q3.columns = ['Session', 'Avg_grades']
mid_avg_Q3.insert(0, "Student Id", 'Q3')

# %%
mid_avg_Q3
# Out:
#   Student Id    Session  Avg_grades
# 0         Q3  Session 2        4.50
# 1         Q3  Session 3        3.50
# 2         Q3  Session 4        5.00
# 3         Q3  Session 5        4.00
# 4         Q3  Session 6        2.75

# %%
mid_all = pd.concat([mid_avg_Q1, mid_avg_Q3])
mid_all
# Out:
#   Student Id    Session  Avg_grades
# 0         Q1  Session 2       0.000
# 1         Q1  Session 3       0.500
# 2         Q1  Session 4       4.000
# 3         Q1  Session 5       3.000
# 4         Q1  Session 6       0.125
# 0         Q3  Session 2       4.500
# 1         Q3  Session 3       3.500
# 2         Q3  Session 4       5.000
# 3         Q3  Session 5       4.000
# 4         Q3  Session 6       2.750

# %%
#cut the long tail after the dot
mid_all['Avg_grades'] = mid_all.apply(lambda x: round(x["Avg_grades"],2), axis=1)

# %%
mid_all
# Out:
#   Student Id    Session  Avg_grades
# 0         Q1  Session 2        0.00
# 1         Q1  Session 3        0.50
# 2         Q1  Session 4        4.00
# 3         Q1  Session 5        3.00
# 4         Q1  Session 6        0.12
# 0         Q3  Session 2        4.50
# 1         Q3  Session 3        3.50
# 2         Q3  Session 4        5.00
# 3         Q3  Session 5        4.00
# 4         Q3  Session 6        2.75
